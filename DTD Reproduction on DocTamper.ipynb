# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# !git clone https://github.com/LeSiIence/DocTamper.git
# %cd DocTamper/models
# !pip install -r requirements.txt
# !pip install torch==1.11.0
# !pip install torchvision==0.12.0
# !pip install lmdb
# !pip install segmentation_models_pytorch
# !pip install timm==0.4.12
# !pip install segmentation_models_pytorch==0.2.1
# !pip install efficientnet_pytorch==0.7.1
# !git clone https://github.com/dwgoon/jpegio.git
# %cd jpegio
# !python setup.py install
# %cd -
# !cp -r '/content/drive/MyDrive/DocTamperV1-FCD' './'
assert os.path.exists('DocTamperV1-FCD')
# !cp '../qt_table.pk' './'
# !cp -r '/content/drive/MyDrive/checkpoints' './pths'
assert os.path.exists('pths')
# !mv pths/vph_imagenet.pt ./
# !mv pths/swin_imagenet.pt ./
# !cp -r '../pks' './'
# Out:
# Mounted at /content/drive/
# Cloning into 'DocTamper'...
# remote: Enumerating objects: 362, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 362 (delta 102), reused 76 (delta 72), pack-reused 245 (from 1)
# Receiving objects: 100% (362/362), 1.52 MiB | 24.29 MiB/s, done.
# Resolving deltas: 100% (192/192), done.
# /content/DocTamper/models
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 MB 37.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 59.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 72.0 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
# ...

# %%
# !git clone https://github.com/LeSiIence/DocTamper.git
# Out:
# Cloning into 'DocTamper'...
# remote: Enumerating objects: 362, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 362 (delta 71), reused 48 (delta 44), pack-reused 279 (from 1)
# Receiving objects: 100% (362/362), 1.52 MiB | 24.30 MiB/s, done.
# Resolving deltas: 100% (192/192), done.

# %%
# !CUDA_VISIBLE_DEVICES=0 python eval_dtd.py --lmdb_name DocTamperV1-FCD --pth pths/dtd_doctamper.pth --minq 75
# Out:
# /content/DocTamper/models/dtd.py:320: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
#   0% 0/334 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 334/334 [00:53<00:00,  6.28it/s]
# [val] iou:[0.99013336 0.74965862] pre:0.8491932577537206 rec:0.7862793428009142 f1:0.816526198370422

# %%
# !ln -s /content/drive/MyDrive/DocTamperV1-SCD ./DocTamperV1-SCD
# !CUDA_VISIBLE_DEVICES=0 python eval_dtd.py --lmdb_name DocTamperV1-SCD --pth pths/dtd_doctamper.pth --minq 75
# Out:
# /content/DocTamper/models/dtd.py:320: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
#   0% 0/3000 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100% 3000/3000 [07:27<00:00,  6.71it/s]
# [val] iou:[0.99682731 0.69193499] pre:0.7451866225004197 rec:0.7629189448853334 f1:0.7539485302695972
